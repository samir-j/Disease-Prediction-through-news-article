# %%
import pandas as pd
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('sentiment_results.csv')
df.head()
# Out:
#                                               tweets  \
# 0                                         Monkey pox
# 1                         course new scam monkey pox
# 2  Monkeypox virtually avoided less random gay se...
# 3           event monkey pox spread dont sex man man
# 4  dont ask source Ive got bad feeling trying get...
#
#                                    lemmatized_tweets  vader_sentiment  \
# 0                                         Monkey pox                0
# 1                         course new scam monkey pox               -1
# 2  Monkeypox virtually avoided less random gay se...                1
# 3           event monkey pox spread dont sex man man                0
# 4  dont ask source Ive got bad feeling trying get...               -1
#
#    textblob_sentiment  vader_compound  textblob_polarity  \
# 0                  -1          0.0000          -0.050000
# 1                   1         -0.5719           0.043182
# 2                  -1          0.1531          -0.083333
# 3                  -1          0.0000          -0.050000
# 4                  -1         -0.4588          -0.700000
#
#    textblob_subjectivity sentiment
# 0               0.000000   Neutral
# 1               0.227273  Negative
# 2               0.383333  Positive
# 3               0.000000   Neutral
# 4               0.666667  Negative

# %%
df['sentiment'] = df['vader_compound'].apply(lambda x: 1 if x > 0 else (0 if x < 0 else 2))
df.head()
# Out:
#                                               tweets  \
# 0                                         Monkey pox
# 1                         course new scam monkey pox
# 2  Monkeypox virtually avoided less random gay se...
# 3           event monkey pox spread dont sex man man
# 4  dont ask source Ive got bad feeling trying get...
#
#                                    lemmatized_tweets  vader_sentiment  \
# 0                                         Monkey pox                0
# 1                         course new scam monkey pox               -1
# 2  Monkeypox virtually avoided less random gay se...                1
# 3           event monkey pox spread dont sex man man                0
# 4  dont ask source Ive got bad feeling trying get...               -1
#
#    textblob_sentiment  vader_compound  textblob_polarity  \
# 0                  -1          0.0000          -0.050000
# 1                   1         -0.5719           0.043182
# 2                  -1          0.1531          -0.083333
# 3                  -1          0.0000          -0.050000
# 4                  -1         -0.4588          -0.700000
#
#    textblob_subjectivity  sentiment
# 0               0.000000          2
# 1               0.227273          0
# 2               0.383333          1
# 3               0.000000          2
# 4               0.666667          0

# %%
train_texts, test_texts, train_labels, test_labels = train_test_split(df['tweets'], df['sentiment'], test_size=0.2, random_state=42)
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, max_length=128)
test_encodings = tokenizer(list(test_texts), truncation=True, padding=True, max_length=128)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 train_encodings = tokenizer(list(train_texts), truncation=True, padding=True, max_length=128)
#       2 test_encodings = tokenizer(list(test_texts), truncation=True, padding=True, max_length=128)
#
# File D:\Anaconda\Lib\site-packages\transformers\tokenization_utils_base.py:2877, in PreTrainedTokenizerBase.__call__(self, text, text_pair, text_target, text_pair_target, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    2875     if not self._in_target_context_manager:
#    2876         self._switch_to_input_mode()
# -> 2877     encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)
#    2878 if text_target is not None:
#    2879     self._switch_to_target_mode()
#
# File D:\Anaconda\Lib\site-packages\transformers\tokenization_utils_base.py:2965, in PreTrainedTokenizerBase._call_one(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    2960         raise ValueError(
#    2961             f"batch length of `text`: {len(text)} does not match batch length of `text_pair`:"
#    2962             f" {len(text_pair)}."
#    2963         )
#    2964     batch_text_or_text_pairs = list(zip(text, text_pair)) if text_pair is not None else text
# -> 2965     return self.batch_encode_plus(
#    2966         batch_text_or_text_pairs=batch_text_or_text_pairs,
#    2967         add_special_tokens=add_special_tokens,
#    2968         padding=padding,
#    2969         truncation=truncation,
#    2970         max_length=max_length,
#    2971         stride=stride,
#    2972         is_split_into_words=is_split_into_words,
#    2973         pad_to_multiple_of=pad_to_multiple_of,
#    2974         padding_side=padding_side,
#    2975         return_tensors=return_tensors,
#    2976         return_token_type_ids=return_token_type_ids,
#    2977         return_attention_mask=return_attention_mask,
#    2978         return_overflowing_tokens=return_overflowing_tokens,
#    2979         return_special_tokens_mask=return_special_tokens_mask,
#    2980         return_offsets_mapping=return_offsets_mapping,
#    2981         return_length=return_length,
#    2982         verbose=verbose,
#    2983         split_special_tokens=split_special_tokens,
#    2984         **kwargs,
#    2985     )
#    2986 else:
#    2987     return self.encode_plus(
#    2988         text=text,
#    2989         text_pair=text_pair,
#    (...)
#    3007         **kwargs,
#    3008     )
#
# File D:\Anaconda\Lib\site-packages\transformers\tokenization_utils_base.py:3167, in PreTrainedTokenizerBase.batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#    3157 # Backward compatibility for 'truncation_strategy', 'pad_to_max_length'
#    3158 padding_strategy, truncation_strategy, max_length, kwargs = self._get_padding_truncation_strategies(
#    3159     padding=padding,
#    3160     truncation=truncation,
#    (...)
#    3164     **kwargs,
#    3165 )
# -> 3167 return self._batch_encode_plus(
#    3168     batch_text_or_text_pairs=batch_text_or_text_pairs,
#    3169     add_special_tokens=add_special_tokens,
#    3170     padding_strategy=padding_strategy,
#    3171     truncation_strategy=truncation_strategy,
#    3172     max_length=max_length,
#    3173     stride=stride,
#    3174     is_split_into_words=is_split_into_words,
#    3175     pad_to_multiple_of=pad_to_multiple_of,
#    3176     padding_side=padding_side,
#    3177     return_tensors=return_tensors,
#    3178     return_token_type_ids=return_token_type_ids,
#    3179     return_attention_mask=return_attention_mask,
#    3180     return_overflowing_tokens=return_overflowing_tokens,
#    3181     return_special_tokens_mask=return_special_tokens_mask,
#    3182     return_offsets_mapping=return_offsets_mapping,
#    3183     return_length=return_length,
#    3184     verbose=verbose,
#    3185     split_special_tokens=split_special_tokens,
#    3186     **kwargs,
#    3187 )
#
# File D:\Anaconda\Lib\site-packages\transformers\tokenization_utils.py:888, in PreTrainedTokenizer._batch_encode_plus(self, batch_text_or_text_pairs, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, padding_side, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, split_special_tokens, **kwargs)
#     885 else:
#     886     ids, pair_ids = ids_or_pair_ids
# --> 888 first_ids = get_input_ids(ids)
#     889 second_ids = get_input_ids(pair_ids) if pair_ids is not None else None
#     890 input_ids.append((first_ids, second_ids))
#
# File D:\Anaconda\Lib\site-packages\transformers\tokenization_utils.py:868, in PreTrainedTokenizer._batch_encode_plus.<locals>.get_input_ids(text)
#     866     return text
#     867 else:
# --> 868     raise ValueError(
#     869         "Input is not valid. Should be a string, a list/tuple of strings or a list/tuple of integers."
#     870     )
#
# ValueError: Input is not valid. Should be a string, a list/tuple of strings or a list/tuple of integers.

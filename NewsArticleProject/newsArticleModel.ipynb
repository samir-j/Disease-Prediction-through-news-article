# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification, pipeline

# Load CSV
df = pd.read_csv("sentiment_results.csv")

# Use lemmatized_tweets column
tweets = df["lemmatized_tweets"].astype(str).tolist()

# Load model
model_name = "cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
sentiment_pipeline = pipeline("sentiment-analysis", model=model, tokenizer=tokenizer)

# Run transformer sentiment analysis
label_map = { "LABEL_0": "Negative", "LABEL_1": "Neutral", "LABEL_2": "Positive" }
results = sentiment_pipeline(tweets, truncation=True)
df["transformer_sentiment"] = [label_map[res["label"]] for res in results]

# Save to new CSV
df.to_csv("tweets_with_transformer_sentiment.csv", index=False)
# Out:
# Device set to use cpu
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 18
#      16 # Run transformer sentiment analysis
#      17 label_map = { "LABEL_0": "Negative", "LABEL_1": "Neutral", "LABEL_2": "Positive" }
# ---> 18 results = sentiment_pipeline(tweets, truncation=True)
#      19 df["transformer_sentiment"] = [label_map[res["label"]] for res in results]
#      21 # Save to new CSV
#
# File D:\Anaconda\Lib\site-packages\transformers\pipelines\text_classification.py:159, in TextClassificationPipeline.__call__(self, inputs, **kwargs)
#     124 """
#     125 Classify the text(s) given as inputs.
#     126
#    (...)
#     156     If `top_k` is used, one such dictionary is returned per label.
#     157 """
# ...
